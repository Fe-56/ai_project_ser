# %%
import pandas as pd

# %%
df = pd.read_csv('../features/combined_features.csv', on_bad_lines='warn')
# Out:
# /var/folders/dv/jnmxtpgn1fj3ff293jj61p6m0000gn/T/ipykernel_36360/194580469.py:1: ParserWarning: Skipping line 4: expected 6375 fields, saw 6376
# Skipping line 43: expected 6375 fields, saw 6376
#
#   df = pd.read_csv('../features/combined_features.csv', on_bad_lines='warn')
# /var/folders/dv/jnmxtpgn1fj3ff293jj61p6m0000gn/T/ipykernel_36360/194580469.py:1: ParserWarning: Skipping line 150: expected 6375 fields, saw 6376
# Skipping line 177: expected 6375 fields, saw 6376
#
#   df = pd.read_csv('../features/combined_features.csv', on_bad_lines='warn')
# /var/folders/dv/jnmxtpgn1fj3ff293jj61p6m0000gn/T/ipykernel_36360/194580469.py:1: ParserWarning: Skipping line 408: expected 6375 fields, saw 6376
# Skipping line 421: expected 6375 fields, saw 6376
# Skipping line 422: expected 6375 fields, saw 6376
#
#   df = pd.read_csv('../features/combined_features.csv', on_bad_lines='warn')
# ...

# %%
full_df = df.set_index("Filepath")

# %%
full_df
# Out:
#                                                 frameTime  \
# Filepath
# ./dataset/crema-d\AudioWAV\1049_ITS_HAP_XX.wav        0.0
# ./dataset/meld\train\dia259_utt0.mp4                  0.0
# ./dataset/meld\train\dia32_utt3.mp4                   0.0
# ./dataset/mlend\MLEndSND_Public\18603.wav             0.0
# ./dataset/mlend\MLEndSND_Public\09082.wav             0.0
# ...                                                   ...
# ./dataset/esd\0017\Surprise\0017_001472.wav           0.0
# ./dataset/tess\OAF_Fear\OAF_choice_fear.wav           0.0
# ./dataset/meld\train\dia972_utt7.mp4                  0.0
# ./dataset/mlend\MLEndSND_Public\12569.wav             0.0
# ./dataset/esd\0017\Surprise\0017_001578.wav           0.0
#
#                                                 audspec_lengthL1norm_sma_range  \
# Filepath
# ./dataset/crema-d\AudioWAV\1049_ITS_HAP_XX.wav                        1.419356
# ./dataset/meld\train\dia259_utt0.mp4                                  1.386165
# ...

# %%
train_set = pd.read_csv('../train_dataset.csv')
train_set
# Out:
#           Id  Dataset                                        Filepath  \
# 0          0    MLEND       ./dataset/mlend\MLEndSND_Public\11093.wav
# 1          1  CREMA-D  ./dataset/crema-d\AudioWAV\1011_TAI_ANG_XX.wav
# 2          2    MLEND       ./dataset/mlend\MLEndSND_Public\27019.wav
# 3          3    MLEND       ./dataset/mlend\MLEndSND_Public\23420.wav
# 4          4  CREMA-D  ./dataset/crema-d\AudioWAV\1077_ITH_ANG_XX.wav
# ...      ...      ...                                             ...
# 44216  44216     MELD            ./dataset/meld\train\dia873_utt1.mp4
# 44217  44217      ESD        ./dataset/esd\0015\Happy\0015_000807.wav
# 44218  44218    MLEND       ./dataset/mlend\MLEndSND_Public\40154.wav
# 44219  44219      ESD          ./dataset/esd\0017\Sad\0017_001347.wav
# 44220  44220    MLEND       ./dataset/mlend\MLEndSND_Public\01986.wav
#
#                   Filename   Ext  Duration   Emotion
# 0                11093.wav  .wav  1.242268  Question
# ...

# %%
cols_to_drop = ['Id', 'Dataset', 'Filename', 'Ext', 'Duration']

# %%
train_df = full_df.merge(train_set, on='Filepath', how='inner')
train_df = train_df.drop(columns=cols_to_drop).set_index('Filepath')

# %%
train_df
# Out:
#                                                 frameTime  \
# Filepath
# ./dataset/crema-d\AudioWAV\1049_ITS_HAP_XX.wav        0.0
# ./dataset/meld\train\dia259_utt0.mp4                  0.0
# ./dataset/mlend\MLEndSND_Public\18603.wav             0.0
# ./dataset/mlend\MLEndSND_Public\09082.wav             0.0
# ./dataset/mlend\MLEndSND_Public\29155.wav             0.0
# ...                                                   ...
# ./dataset/esd\0020\Surprise\0020_001469.wav           0.0
# ./dataset/tess\OAF_angry\OAF_pain_angry.wav           0.0
# ./dataset/esd\0017\Surprise\0017_001472.wav           0.0
# ./dataset/meld\train\dia972_utt7.mp4                  0.0
# ./dataset/mlend\MLEndSND_Public\12569.wav             0.0
#
#                                                 audspec_lengthL1norm_sma_range  \
# Filepath
# ./dataset/crema-d\AudioWAV\1049_ITS_HAP_XX.wav                        1.419356
# ./dataset/meld\train\dia259_utt0.mp4                                  1.386165
# ...

# %%
X_train = train_df.iloc[:, :-1]
y_train = train_df.iloc[:, -1]

print(f"Features shape: {X_train.shape}")
print(f"Target shape: {y_train.shape}")
# Out:
# Features shape: (43566, 6374)
# Target shape: (43566,)

# %%
y_train
# Out:
# Filepath
# ./dataset/crema-d\AudioWAV\1049_ITS_HAP_XX.wav       Happy
# ./dataset/meld\train\dia259_utt0.mp4                  Fear
# ./dataset/mlend\MLEndSND_Public\18603.wav            Happy
# ./dataset/mlend\MLEndSND_Public\09082.wav            Bored
# ./dataset/mlend\MLEndSND_Public\29155.wav         Question
#                                                     ...
# ./dataset/esd\0020\Surprise\0020_001469.wav       Surprise
# ./dataset/tess\OAF_angry\OAF_pain_angry.wav          Anger
# ./dataset/esd\0017\Surprise\0017_001472.wav       Surprise
# ./dataset/meld\train\dia972_utt7.mp4                   Sad
# ./dataset/mlend\MLEndSND_Public\12569.wav          Neutral
# Name: Emotion, Length: 43566, dtype: object

# %%
from FeaturePreprocessor import FeaturePreprocessor
preprocessor = FeaturePreprocessor(n_components_pca=0.99, n_features_select=50)

# %%
# Normalize features
X_train_normalized = preprocessor.normalize_features(X_train)

# Reduce dimensions
X_train_reduced = preprocessor.reduce_dimensions(X_train_normalized, y_train, fit=True)

# Normalize features
X_train_final = preprocessor.normalize_pc(X_train_reduced)
# Out:
# Input shape before PCA: (43566, 6374)
# Selecting 50 features

# %%
res = {"X_train": X_train_final, "y_train": y_train}
type(res["y_train"])
# Out:
# pandas.core.series.Series

# %%
import torch
X_train_tensor = torch.tensor(res["X_train"].values, dtype=torch.float32)
print(X_train_tensor.shape)
y_train_tensor = torch.tensor(res["y_train"].values, dtype=torch.int32)
# Out:
# torch.Size([43566, 50])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       2 X_train_tensor = torch.tensor(res["X_train"].values, dtype=torch.float32)
#       3 print(X_train_tensor.shape)
# ----> 4 y_train_tensor = torch.tensor(res["y_train"].values, dtype=torch.int32)
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint64, uint32, uint16, uint8, and bool.
