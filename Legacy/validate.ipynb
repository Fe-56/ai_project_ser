# %%
import pandas as pd

# %%
ori_train = pd.read_csv('train_dataset.csv')
ori_train
# Out:
#           Id  Dataset                                        Filepath  \
# 0      26594    MLEND       ./dataset/mlend\MLEndSND_Public\13233.wav
# 1      60526      ESD        ./dataset/esd\0014\Angry\0014_000473.wav
# 2      64643      ESD          ./dataset/esd\0016\Sad\0016_001090.wav
# 3      17330     MELD            ./dataset/meld\train\dia992_utt1.mp4
# 4      43991    MLEND       ./dataset/mlend\MLEndSND_Public\38261.wav
# ...      ...      ...                                             ...
# 59758  45859    MLEND       ./dataset/mlend\MLEndSND_Public\40971.wav
# 59759   3169  CREMA-D  ./dataset/crema-d\AudioWAV\1039_TSI_FEA_XX.wav
# 59760  60185      ESD      ./dataset/esd\0014\Neutral\0014_000132.wav
# 59761  39433    MLEND       ./dataset/mlend\MLEndSND_Public\31771.wav
# 59762  46849    MLEND       ./dataset/mlend\MLEndSND_Public\42435.wav
#
#                   Filename   Ext      Speaker  \
# 0                13233.wav  .wav     Mlend_20
# ...

# %%
ori_test = pd.read_csv('test_dataset.csv')
ori_test
# Out:
#           Id    Dataset                                           Filepath  \
# 0      23600      MLEND          ./dataset/mlend\MLEndSND_Public\08909.wav
# 1      18884      MLEND          ./dataset/mlend\MLEndSND_Public\02061.wav
# 2      27903      MLEND          ./dataset/mlend\MLEndSND_Public\15117.wav
# 3      32786      MLEND          ./dataset/mlend\MLEndSND_Public\22148.wav
# 4       6240    CREMA-D     ./dataset/crema-d\AudioWAV\1077_ITH_ANG_XX.wav
# ...      ...        ...                                                ...
# 14936  26705      MLEND          ./dataset/mlend\MLEndSND_Public\13387.wav
# 14937  73320  JL-CORPUS  ./dataset/jl-corpus/Raw JL corpus (unchecked a...
# 14938  43651      MLEND          ./dataset/mlend\MLEndSND_Public\37789.wav
# 14939  50930    RAVDESS  ./dataset/ravdess\Actor_15\03-01-02-01-02-01-1...
# 14940  72337  JL-CORPUS  ./dataset/jl-corpus/Raw JL corpus (unchecked a...
#
#                        Filename   Ext           Speaker  \
# ...

# %%
new_train = pd.read_csv('train_dataset_remake.csv')
new_train
# Out:
#           Id  Dataset                                        Filepath  \
# 0      26594    MLEND       ./dataset/mlend\MLEndSND_Public\13233.wav
# 1      60526      ESD        ./dataset/esd\0014\Angry\0014_000473.wav
# 2      64643      ESD          ./dataset/esd\0016\Sad\0016_001090.wav
# 3      17330     MELD            ./dataset/meld\train\dia992_utt1.mp4
# 4      43991    MLEND       ./dataset/mlend\MLEndSND_Public\38261.wav
# ...      ...      ...                                             ...
# 59758  45859    MLEND       ./dataset/mlend\MLEndSND_Public\40971.wav
# 59759   3169  CREMA-D  ./dataset/crema-d\AudioWAV\1039_TSI_FEA_XX.wav
# 59760  60185      ESD      ./dataset/esd\0014\Neutral\0014_000132.wav
# 59761  39433    MLEND       ./dataset/mlend\MLEndSND_Public\31771.wav
# 59762  46849    MLEND       ./dataset/mlend\MLEndSND_Public\42435.wav
#
#                   Filename   Ext   Emotion
# 0                13233.wav  .wav     Bored
# ...

# %%
new_test = pd.read_csv('test_dataset_remake.csv')
new_test
# Out:
#           Id    Dataset                                           Filepath  \
# 0      23600      MLEND          ./dataset/mlend\MLEndSND_Public\08909.wav
# 1      18884      MLEND          ./dataset/mlend\MLEndSND_Public\02061.wav
# 2      27903      MLEND          ./dataset/mlend\MLEndSND_Public\15117.wav
# 3      32786      MLEND          ./dataset/mlend\MLEndSND_Public\22148.wav
# 4       6240    CREMA-D     ./dataset/crema-d\AudioWAV\1077_ITH_ANG_XX.wav
# ...      ...        ...                                                ...
# 14936  26705      MLEND          ./dataset/mlend\MLEndSND_Public\13387.wav
# 14937  73320  JL-CORPUS  ./dataset/jl-corpus/Raw JL corpus (unchecked a...
# 14938  43651      MLEND          ./dataset/mlend\MLEndSND_Public\37789.wav
# 14939  50930    RAVDESS  ./dataset/ravdess\Actor_15\03-01-02-01-02-01-1...
# 14940  72337  JL-CORPUS  ./dataset/jl-corpus/Raw JL corpus (unchecked a...
#
#                        Filename   Ext  Emotion
# ...

# %%
print(ori_train['Id'].tolist() == new_train['Id'].tolist())
print(ori_train['Dataset'].tolist() == new_train['Dataset'].tolist())
print(ori_train['Filename'].tolist() == new_train['Filename'].tolist())
print(ori_train['Filepath'].tolist() == new_train['Filepath'].tolist())
print(ori_train['Ext'].tolist() == new_train['Ext'].tolist())
print(ori_train['Emotion'].tolist() == new_train['Emotion'].tolist())

print(ori_test['Id'].tolist() == new_test['Id'].tolist())
print(ori_test['Dataset'].tolist() == new_test['Dataset'].tolist())
print(ori_test['Filename'].tolist() == new_test['Filename'].tolist())
print(ori_test['Filepath'].tolist() == new_test['Filepath'].tolist())
print(ori_test['Ext'].tolist() == new_test['Ext'].tolist())
print(ori_test['Emotion'].tolist() == new_test['Emotion'].tolist())
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
